# %% [markdown]
#   # Capstone AAA Projet                     Martin George mgeorgevienna@gmail.com

# %% [markdown]
# # Visualization of location data using Folium tools

# %% [markdown]
# ### Reading Excel file in to

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data = pd.read_csv('member_sample.csv', index_col = 0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21344 entries, 0 to 99998
# Columns: 112 entries, Individual Key to Was Towed To AAR Referral
# dtypes: float64(35), object(77)
# memory usage: 18.4+ MB

# %%
data.head()
# Out:
#    Individual Key  Household Key Member Flag          City State - Grouped  \
# 0      10000003.0     10462590.0           Y     NEW HAVEN              CT
# 1      52211550.0      4500791.0           Y  WEST WARWICK              RI
# 2      52211550.0      4500791.0           Y  WEST WARWICK              RI
# 3      52211550.0      4500791.0           Y  WEST WARWICK              RI
# 4      52211550.0      4500791.0           Y  WEST WARWICK              RI
#
#      ZIP5        ZIP9 FSV CMSI Flag FSV Credit Card Flag  \
# 0  6511.0  65111349.0             N                    N
# 1  2893.0  28933850.0             N                    Y
# 2  2893.0  28933850.0             N                    Y
# 3  2893.0  28933850.0             N                    Y
# 4  2893.0  28933850.0             N                    Y
#
#   FSV Deposit Program Flag  ... SC Vehicle Manufacturer Name  \
# 0                        N  ...                          NaN
# ...

# %%
data[['Tow Destination Latitude','Tow Destination Longitude']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21344 entries, 0 to 99998
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Tow Destination Latitude   11813 non-null  float64
#  1   Tow Destination Longitude  11813 non-null  float64
# dtypes: float64(2)
# memory usage: 500.2 KB

# %%
lat_long_0 = data[['Tow Destination Latitude','Tow Destination Longitude']].dropna().iloc[:5000]
lat_long = data[['Tow Destination Latitude','Tow Destination Longitude','Total Cost']].dropna().iloc[:5000]

# %%
lat_long.head()
# Out:
#    Tow Destination Latitude  Tow Destination Longitude  Total Cost
# 1                      41.0                      -71.0        32.5
# 2                       0.0                        0.0        30.0
# 3                       0.0                        0.0        32.5
# 4                       0.0                        0.0        30.0
# 5                       0.0                        0.0        53.0

# %%
# !pip install folium

# %%
import folium

# %%
loc_1 = lat_long_0.iloc[0]

# %%
loc_1
# Out:
# Tow Destination Latitude     41.0
# Tow Destination Longitude   -71.0
# Name: 1, dtype: float64

# %%
#loc = data[['Tow Destination Latitude','Tow Destination Longitude','Total Cost']].dropna()
#loc.head()
#loc.shape
# Out:
# (11798, 3)

# %%
m = folium.Map(location = loc_1)

# %%
def add_marker(x):
    folium.CircleMarker(location = [x[0],x[1]], radius = x[2]/5).add_to(m)

# %%
lat_long.apply(add_marker, axis = 1)
# Out:
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
#          ...
# 16344    None
# 16345    None
# 16348    None
# 16349    None
# 16354    None
# Length: 5000, dtype: object

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Conclusion: This graphical visualization clearly shows that some of the existing data on Tow destination is wrong. Circle size shows the how the total cost associated with each Tow.
